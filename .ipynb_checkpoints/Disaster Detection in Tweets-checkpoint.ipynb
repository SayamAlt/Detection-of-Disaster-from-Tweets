# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from nltk.corpus import stopwords
import re, string
from symspellpy import SymSpell, Verbosity
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score
from xgboost import XGBClassifier
import xgboost as xgb
from wordcloud import WordCloud

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
test = pd.read_csv('test.csv')
test.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
train['keyword'] = train['keyword'].apply(lambda x: str.lower(x) if pd.isna(x) != True else x)
train['location'] = train['location'].apply(lambda x: str.lower(x) if pd.isna(x) != True else x)
train['text'] = train['text'].apply(lambda x: str.lower(x) if pd.isna(x) != True else x)
test['keyword'] = test['keyword'].apply(lambda x: str.lower(x) if pd.isna(x) != True else x)
test['location'] = test['location'].apply(lambda x: str.lower(x) if pd.isna(x) != True else x)
test['text'] = test['text'].apply(lambda x: str.lower(x) if pd.isna(x) != True else x)

# %%
def text_process(text):
    nopunc = [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    return ' '.join([word for word in nopunc.split() if word.lower() not in stopwords.words('english') and not word.isdigit()])

# %%
train['keyword'] = train['keyword'].apply(lambda x: text_process(x) if pd.isna(x) != True else x)
train['location'] = train['location'].apply(lambda x: text_process(x) if pd.isna(x) != True else x)
train['text'] = train['text'].apply(lambda x: text_process(x) if pd.isna(x) != True else x)
test['keyword'] = test['keyword'].apply(lambda x: text_process(x) if pd.isna(x) != True else x)
test['location'] = test['location'].apply(lambda x: text_process(x) if pd.isna(x) != True else x)
test['text'] = test['text'].apply(lambda x: text_process(x) if pd.isna(x) != True else x)

# %%
train['keyword'] = train['keyword'].apply(lambda x: re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ", x) if pd.isna(x) != True else x)
train['location'] = train['location'].apply(lambda x: re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ", x) if pd.isna(x) != True else x)
train['text'] = train['text'].apply(lambda x: re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ", x) if pd.isna(x) != True else x)
test['keyword'] = test['keyword'].apply(lambda x: re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ", x) if pd.isna(x) != True else x)
test['location'] = test['location'].apply(lambda x: re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ", x) if pd.isna(x) != True else x)
test['text'] = test['text'].apply(lambda x: re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ", x) if pd.isna(x) != True else x)

# %%
sym_spell = SymSpell()
def spelling_correction(text):
    correct_spellings = []
    for token in text.split():
        x = sym_spell.lookup(token,Verbosity.CLOSEST,max_edit_distance=2,include_unknown=True)[0].__str__()
        y = x.split(',')[0]
        correct_spellings.append(y)
    return ' '.join(correct_spellings)

# %%
train['keyword'] = train['keyword'].apply(lambda x: spelling_correction(x) if pd.isna(x) != True else x)
train['location'] = train['location'].apply(lambda x: spelling_correction(x) if pd.isna(x) != True else x)
train['text'] = train['text'].apply(lambda x: spelling_correction(x) if pd.isna(x) != True else x)
test['keyword'] = test['keyword'].apply(lambda x: spelling_correction(x) if pd.isna(x) != True else x)
test['location'] = test['location'].apply(lambda x: spelling_correction(x) if pd.isna(x) != True else x)
test['text'] = test['text'].apply(lambda x: spelling_correction(x) if pd.isna(x) != True else x)

# %%
stemmer = PorterStemmer()

def stem_words(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train['keyword'] = train['keyword'].apply(lambda x: stem_words(x) if pd.isna(x) != True else x)
train['location'] = train['location'].apply(lambda x: stem_words(x) if pd.isna(x) != True else x)
train['text'] = train['text'].apply(lambda x: stem_words(x) if pd.isna(x) != True else x)
test['keyword'] = test['keyword'].apply(lambda x: stem_words(x) if pd.isna(x) != True else x)
test['location'] = test['location'].apply(lambda x: stem_words(x) if pd.isna(x) != True else x)
test['text'] = test['text'].apply(lambda x: stem_words(x) if pd.isna(x) != True else x)

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_words(text):
    return ' '.join([lemmatizer.lemmatize(word) for word in text.split()])

train['keyword'] = train['keyword'].apply(lambda x: lemmatize_words(x) if pd.isna(x) != True else x)
train['location'] = train['location'].apply(lambda x: lemmatize_words(x) if pd.isna(x) != True else x)
train['text'] = train['text'].apply(lambda x: lemmatize_words(x) if pd.isna(x) != True else x)
test['keyword'] = test['keyword'].apply(lambda x: lemmatize_words(x) if pd.isna(x) != True else x)
test['location'] = test['location'].apply(lambda x: lemmatize_words(x) if pd.isna(x) != True else x)
test['text'] = test['text'].apply(lambda x: lemmatize_words(x) if pd.isna(x) != True else x)

# %%
for col in train.columns:
    print("% of null values in {} =".format(col),str(np.round(train[col].isnull().sum()/len(train[col]),2)) + '%')
# Out:
# % of null values in id = 0.0%
# % of null values in keyword = 0.01%
# % of null values in location = 0.33%
# % of null values in text = 0.0%
# % of null values in target = 0.0%

# %%
train['location'].fillna('Unavailable',inplace=True)
test['location'].fillna('Unavailable',inplace=True)

# %%
train['keyword']=train['keyword'].fillna('None')
test['keyword']=test['keyword'].fillna('None')

# %% [markdown]
# # Exploratory Data Analysis

# %%
disaster_tweets = ' '.join(list(train[train['target'] == 1]['text']))
data_wc = WordCloud(width = 600, height = 512).generate(disaster_tweets)
plt.figure(figsize = (13, 9))
plt.imshow(data_wc)
plt.show()

# %%
non_disaster_tweets = ' '.join(list(train[train['target'] == 0]['text']))
data_wc = WordCloud(width = 600, height = 512).generate(non_disaster_tweets)
plt.figure(figsize = (13, 9))
plt.imshow(data_wc)
plt.show()

# %%
sns.countplot(train['target'],palette='plasma')
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %% [markdown]
# # Text Vectorization

# %%
vectorizer = CountVectorizer()

bow_text = vectorizer.fit_transform(train.text)
bow_text_test = vectorizer.transform(test.text)
bow_text
# Out:
# <7613x18866 sparse matrix of type '<class 'numpy.int64'>'
# 	with 72139 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Model Training and Evaluation

# %%
text_train, text_test, target_train, target_test = train_test_split(bow_text,train['target'],test_size=0.35)

# %%
mnb = MultinomialNB()
mnb.fit(text_train,target_train)
# Out:
# MultinomialNB()

# %%
predictions = mnb.predict(text_test)
predictions
# Out:
# array([0, 1, 1, ..., 0, 1, 0], dtype=int64)

# %%
print(confusion_matrix(target_test,predictions))
print(classification_report(target_test,predictions))
# Out:
# [[1295  194]
#  [ 325  851]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83      1489
#            1       0.81      0.72      0.77      1176
#
#     accuracy                           0.81      2665
#    macro avg       0.81      0.80      0.80      2665
# weighted avg       0.81      0.81      0.80      2665

# %%
param_grid = {'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0.00001]}

# %%
grid_search = GridSearchCV(MultinomialNB(),param_grid,refit=True,verbose=3)
grid_search.fit(text_train,target_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END ...........................alpha=1;, score=0.784 total time=   0.0s
# [CV 2/5] END ...........................alpha=1;, score=0.805 total time=   0.0s
# [CV 3/5] END ...........................alpha=1;, score=0.804 total time=   0.0s
# [CV 4/5] END ...........................alpha=1;, score=0.790 total time=   0.0s
# [CV 5/5] END ...........................alpha=1;, score=0.795 total time=   0.0s
# [CV 1/5] END .........................alpha=0.1;, score=0.776 total time=   0.0s
# [CV 2/5] END .........................alpha=0.1;, score=0.792 total time=   0.0s
# [CV 3/5] END .........................alpha=0.1;, score=0.791 total time=   0.0s
# [CV 4/5] END .........................alpha=0.1;, score=0.774 total time=   0.0s
# [CV 5/5] END .........................alpha=0.1;, score=0.780 total time=   0.0s
# [CV 1/5] END ........................alpha=0.01;, score=0.777 total time=   0.0s
# [CV 2/5] END ........................alpha=0.01;, score=0.776 total time=   0.0s
# [CV 3/5] END ........................alpha=0.01;, score=0.778 total time=   0.0s
# [CV 4/5] END ........................alpha=0.01;, score=0.761 total time=   0.0s
# [CV 5/5] END ........................alpha=0.01;, score=0.757 total time=   0.0s
# [CV 1/5] END .......................alpha=0.001;, score=0.768 total time=   0.0s
# [CV 2/5] END .......................alpha=0.001;, score=0.770 total time=   0.0s
# [CV 3/5] END .......................alpha=0.001;, score=0.770 total time=   0.0s
# [CV 4/5] END .......................alpha=0.001;, score=0.754 total time=   0.0s
# [CV 5/5] END .......................alpha=0.001;, score=0.753 total time=   0.0s
# [CV 1/5] END ......................alpha=0.0001;, score=0.764 total time=   0.0s
# [CV 2/5] END ......................alpha=0.0001;, score=0.768 total time=   0.0s
# [CV 3/5] END ......................alpha=0.0001;, score=0.769 total time=   0.0s
# [CV 4/5] END ......................alpha=0.0001;, score=0.752 total time=   0.0s
# [CV 5/5] END ......................alpha=0.0001;, score=0.751 total time=   0.0s
# [CV 1/5] END .......................alpha=1e-05;, score=0.764 total time=   0.0s
# [CV 2/5] END .......................alpha=1e-05;, score=0.768 total time=   0.0s
# [CV 3/5] END .......................alpha=1e-05;, score=0.768 total time=   0.0s
# [CV 4/5] END .......................alpha=1e-05;, score=0.752 total time=   0.0s
# [CV 5/5] END .......................alpha=1e-05;, score=0.751 total time=   0.0s
# GridSearchCV(estimator=MultinomialNB(),
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 1e-05]},
#              verbose=3)

# %%
grid_search.best_score_
# Out:
# 0.7954716017607828

# %%
optimized_mnb = grid_search.predict(text_test)
optimized_mnb
# Out:
# array([0, 1, 1, ..., 0, 1, 0], dtype=int64)

# %%
print(confusion_matrix(target_test,optimized_mnb))
print(classification_report(target_test,optimized_mnb))
# Out:
# [[1295  194]
#  [ 325  851]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83      1489
#            1       0.81      0.72      0.77      1176
#
#     accuracy                           0.81      2665
#    macro avg       0.81      0.80      0.80      2665
# weighted avg       0.81      0.81      0.80      2665

# %%
logmodel = LogisticRegression()
logmodel.fit(text_train,target_train)
# Out:
# LogisticRegression()

# %%
lr_pred = logmodel.predict(text_test)
lr_pred
# Out:
# array([0, 1, 1, ..., 0, 1, 0], dtype=int64)

# %%
print(confusion_matrix(target_test,lr_pred))
print(classification_report(target_test,lr_pred))
# Out:
# [[1306  183]
#  [ 375  801]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.82      1489
#            1       0.81      0.68      0.74      1176
#
#     accuracy                           0.79      2665
#    macro avg       0.80      0.78      0.78      2665
# weighted avg       0.79      0.79      0.79      2665

# %%
rfc = RandomForestClassifier(n_estimators=2)
rfc.fit(text_train,target_train)
# Out:
# RandomForestClassifier(n_estimators=2)

# %%
rfc_pred = rfc.predict(text_test)
rfc_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
print(confusion_matrix(target_test,rfc_pred))
print(classification_report(target_test,rfc_pred))
# Out:
# [[1392   97]
#  [ 709  467]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.93      0.78      1489
#            1       0.83      0.40      0.54      1176
#
#     accuracy                           0.70      2665
#    macro avg       0.75      0.67      0.66      2665
# weighted avg       0.74      0.70      0.67      2665

# %%
dtree = DecisionTreeClassifier()
dtree.fit(text_train,target_train)
# Out:
# DecisionTreeClassifier()

# %%
dtree_pred = dtree.predict(text_test)
dtree_pred
# Out:
# array([0, 1, 1, ..., 0, 1, 0], dtype=int64)

# %%
print(confusion_matrix(target_test,dtree_pred))
print(classification_report(target_test,dtree_pred))
# Out:
# [[1228  261]
#  [ 395  781]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79      1489
#            1       0.75      0.66      0.70      1176
#
#     accuracy                           0.75      2665
#    macro avg       0.75      0.74      0.75      2665
# weighted avg       0.75      0.75      0.75      2665

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(text_train,target_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
knn_pred = knn.predict(text_test)
knn_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
print(confusion_matrix(target_test,knn_pred))
print(classification_report(target_test,knn_pred))
# Out:
# [[1477   12]
#  [ 888  288]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77      1489
#            1       0.96      0.24      0.39      1176
#
#     accuracy                           0.66      2665
#    macro avg       0.79      0.62      0.58      2665
# weighted avg       0.77      0.66      0.60      2665

# %%
param_grid = {'n_neighbors': [1,2,3,4,5], 
              'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'], 
              'weights': ['uniform','distance'],
              'p': [1,2]}

# %%
grid_search = GridSearchCV(KNeighborsClassifier(),param_grid,refit=True,verbose=3)
grid_search
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [1, 2, 3, 4, 5], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              verbose=3)

# %%
grid_search.fit(text_train,target_train)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [CV 1/5] END algorithm=auto, n_neighbors=1, p=1, weights=uniform;, score=0.700 total time=   0.0s
# [CV 2/5] END algorithm=auto, n_neighbors=1, p=1, weights=uniform;, score=0.689 total time=   0.0s
# [CV 3/5] END algorithm=auto, n_neighbors=1, p=1, weights=uniform;, score=0.672 total time=   0.0s
# [CV 4/5] END algorithm=auto, n_neighbors=1, p=1, weights=uniform;, score=0.678 total time=   0.0s
# [CV 5/5] END algorithm=auto, n_neighbors=1, p=1, weights=uniform;, score=0.692 total time=   0.0s
# [CV 1/5] END algorithm=auto, n_neighbors=1, p=1, weights=distance;, score=0.700 total time=   0.0s
# [CV 2/5] END algorithm=auto, n_neighbors=1, p=1, weights=distance;, score=0.689 total time=   0.0s
# [CV 3/5] END algorithm=auto, n_neighbors=1, p=1, weights=distance;, score=0.672 total time=   0.0s
# [CV 4/5] END algorithm=auto, n_neighbors=1, p=1, weights=distance;, score=0.678 total time=   0.0s
# [CV 5/5] END algorithm=auto, n_neighbors=1, p=1, weights=distance;, score=0.692 total time=   0.0s
# [CV 1/5] END algorithm=auto, n_neighbors=1, p=2, weights=uniform;, score=0.697 total time=   0.0s
# [CV 2/5] END algorithm=auto, n_neighbors=1, p=2, weights=uniform;, score=0.688 total time=   0.0s
# [CV 3/5] END algorithm=auto, n_neighbors=1, p=2, weights=uniform;, score=0.674 total time=   0.0s
# [CV 4/5] END algorithm=auto, n_neighbors=1, p=2, weights=uniform;, score=0.685 total time=   0.0s
# [CV 5/5] END algorithm=auto, n_neighbors=1, p=2, weights=uniform;, score=0.693 total time=   0.0s
# [CV 1/5] END algorithm=auto, n_neighbors=1, p=2, weights=distance;, score=0.697 total time=   0.0s
# [CV 2/5] END algorithm=auto, n_neighbors=1, p=2, weights=distance;, score=0.688 total time=   0.0s
# [CV 3/5] END algorithm=auto, n_neighbors=1, p=2, weights=distance;, score=0.674 total time=   0.0s
# [CV 4/5] END algorithm=auto, n_neighbors=1, p=2, weights=distance;, score=0.685 total time=   0.0s
# [CV 5/5] END algorithm=auto, n_neighbors=1, p=2, weights=distance;, score=0.693 total time=   0.0s
# [CV 1/5] END algorithm=auto, n_neighbors=2, p=1, weights=uniform;, score=0.680 total time=   0.0s
# [CV 2/5] END algorithm=auto, n_neighbors=2, p=1, weights=uniform;, score=0.674 total time=   0.0s
# [CV 3/5] END algorithm=auto, n_neighbors=2, p=1, weights=uniform;, score=0.666 total time=   0.0s
# [CV 4/5] END algorithm=auto, n_neighbors=2, p=1, weights=uniform;, score=0.668 total time=   0.1s
# [CV 5/5] END algorithm=auto, n_neighbors=2, p=1, weights=uniform;, score=0.655 total time=   0.0s
# [CV 1/5] END algorithm=auto, n_neighbors=2, p=1, weights=distance;, score=0.703 total time=   0.0s
# [CV 2/5] END algorithm=auto, n_neighbors
total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=2, p=1, weights=distance;, score=0.681 total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=2, p=1, weights=distance;, score=0.694 total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=2, p=2, weights=uniform;, score=0.682 total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=2, p=2, weights=uniform;, score=0.675 total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=2, p=2, weights=uniform;, score=0.668 total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=2, p=2, weights=uniform;, score=0.670 total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=2, p=2, weights=uniform;, score=0.656 total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=2, p=2, weights=distance;, score=0.703 total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=2, p=2, weights=distance;, score=0.690 total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=2, p=2, weights=distance;, score=0.686 total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=2, p=2, weights=distance;, score=0.687 total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=2, p=2, weights=distance;, score=0.696 total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=3, p=1, weights=uniform;, score=0.683 total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=3, p=1, weights=uniform;, score=0.679 total time=   0.1s
# [CV 3/5] END algorithm=brute, n_neighbors=3, p=1, weights=uniform;, score=0.671 total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=3, p=1, weights=uniform;, score=0.672 total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=3, p=1, weights=uniform;, score=0.671 total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=3, p=1, weights=distance;, score=0.694 total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=3, p=1, weights=distance;, score=0.685 total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=3, p=1, weights=distance;, score=0.678 total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=3, p=1, weights=distance;, score=0.683 total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=3, p=1, weights=distance;, score=0.685 total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=3, p=2, weights=uniform;, score=0.685 total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=3, p=2, weights=uniform;, score=0.677 total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=3, p=2, weights=uniform;, score=0.675 total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=3, p=2, weights=uniform;, score=0.675 total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=3, p=2, weights=uniform;, score=0.673 total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=3, p=2, weights=distance;, score=0.692 total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=3, p=2, weights=distance;, score=0.678 total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=3, p=2, weights=distance;, score=0.677 total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=3, p=2, weights=distance;, score=0.679 total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=3, p=2, weights=distance;, score=0.675 total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=4, p=1, weights=uniform;, score=0.664 total time=   0.1s
# [CV 2/5] END algorithm=brute, n_neighbors=4, p=1, weights=uniform;, score=0.653 total time=   0.1s
# [CV 3/5] END algorithm=brute, n_neighbors=4, p=1, weights=uniform;, score=0.652 total time=   0.1s
# [CV 4/5] END algorithm=brute, n_neighbors=4, p=1, weights=uniform;, score=0.648 total time=   0.1s
# [CV 5/5] END algorithm=brute, n_neighbors=4, p=1, weights=uniform;, score=0.651 total time=   0.1s
# [CV 1/5] END algorithm=brute, n_neighbors=4, p=1, weights=distance;, score=0.697 total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=4, p=1, weights=distance;, score=0.681 total time=   0.1s
# [CV 3/5] END algorithm=brute, n_neighbors=4, p=1, weights=distance;, score=0.680 total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=4, p=1, weights=distance;, score=0.677 total time=   0.1s
# [CV 5/5] END algorithm=brute, n_neighbors=4, p=1, weights=distance;, score=0.677 total time=   0.1s
# [CV 1/5] END algorithm=brute, n_neighbors=4, p=2, weights=uniform;, score=0.668 total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=4, p=2, weights=uniform;, score=0.656 total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=4, p=2, weights=uniform;, score=0.657 total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=4, p=2, weights=uniform;, score=0.651 total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=4, p=2, weights=uniform;, score=0.654 total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=4, p=2, weights=distance;, score=0.692 total time=   0.0s
# [CV 2/5] END algorithm=brute, n_neighbors=4, p=2, weights=distance;, score=0.688 total time=   0.0s
# [CV 3/5] END algorithm=brute, n_neighbors=4, p=2, weights=distance;, score=0.682 total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=4, p=2, weights=distance;, score=0.675 total time=   0.0s
# [CV 5/5] END algorithm=brute, n_neighbors=4, p=2, weights=distance;, score=0.680 total time=   0.0s
# [CV 1/5] END algorithm=brute, n_neighbors=5, p=1, weights=uniform;, score=0.662 total time=   0.1s
# [CV 2/5] END algorithm=brute, n_neighbors=5, p=1, weights=uniform;, score=0.655 total time=   0.1s
# [CV 3/5] END algorithm=brute, n_neighbors=5, p=1, weights=uniform;, score=0.658 total time=   0.1s
# [CV 4/5] END algorithm=brute, n_neighbors=5, p=1, weights=uniform;, score=0.651 total time=   0.2s
# [CV 5/5] END algorithm=brute, n_neighbors=5, p=1, weights=uniform;, score=0.651 total time=   0.3s
# [CV 1/5] END algorithm=brute, n_neighbors=5, p=1, weights=distance;, score=0.680 total time=   0.2s
# [CV 2/5] END algorithm=brute, n_neighbors=5, p=1, weights=distance;, score=0.670 total time=   0.2s
# [CV 3/5] END algorithm=brute, n_neighbors=5, p=1, weights=distance;, score=0.666 total time=   0.1s
# [CV 4/5] END algorithm=brute, n_neighbors=5, p=1, weights=distance;, score=0.670 total time=   0.2s
# [CV 5/5] END algorithm=brute, n_neighbors=5, p=1, weights=distance;, score=0.668 total time=   0.2s
# [CV 1/5] END algorithm=brute, n_neighbors=5, p=2, weights=uniform;, score=0.666 total time=   0.1s
# [CV 2/5] END algorithm=brute, n_neighbors=5, p=2, weights=uniform;, score=0.656 total time=   0.1s
# [CV 3/5] END algorithm=brute, n_neighbors=5, p=2, weights=uniform;, score=0.659 total time=   0.1s
# [CV 4/5] END algorithm=brute, n_neighbors=5, p=2, weights=uniform;, score=0.651 total time=   0.1s
# [CV 5/5] END algorithm=brute, n_neighbors=5, p=2, weights=uniform;, score=0.654 total time=   0.1s
# [CV 1/5] END algorithm=brute, n_neighbors=5, p=2, weights=distance;, score=0.678 total time=   0.1s
# [CV 2/5] END algorithm=brute, n_neighbors=5, p=2, weights=distance;, score=0.666 total time=   0.1s
# [CV 3/5] END algorithm=brute, n_neighbors=5, p=2, weights=distance;, score=0.664 total time=   0.0s
# [CV 4/5] END algorithm=brute, n_neighbors=5, p=2, weights=distance;, score=0.664 total time=   0.1s
# [CV 5/5] END algorithm=brute, n_neighbors=5, p=2, weights=distance;, score=0.661 total time=   0.1s
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [1, 2, 3, 4, 5], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              verbose=3)

# %%
grid_search.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=2, weights='distance')

# %%
grid_search.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 2, 'p': 2, 'weights': 'distance'}

# %%
grid_search.best_score_
# Out:
# 0.6921984251003461

# %%
optimized_knn = grid_search.predict(text_test)
optimized_knn
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
print(confusion_matrix(target_test,optimized_knn))
print(classification_report(target_test,optimized_knn))
# Out:
# [[1410   79]
#  [ 750  426]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77      1489
#            1       0.84      0.36      0.51      1176
#
#     accuracy                           0.69      2665
#    macro avg       0.75      0.65      0.64      2665
# weighted avg       0.74      0.69      0.66      2665

# %%
svm = SVC()
svm.fit(text_train,target_train)
# Out:
# SVC()

# %%
svm_pred = svm.predict(text_test)
svm_pred
# Out:
# array([0, 1, 0, ..., 0, 1, 0], dtype=int64)

# %%
print(confusion_matrix(target_test,svm_pred))
print(classification_report(target_test,svm_pred))
# Out:
# [[1375  114]
#  [ 429  747]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.84      1489
#            1       0.87      0.64      0.73      1176
#
#     accuracy                           0.80      2665
#    macro avg       0.81      0.78      0.78      2665
# weighted avg       0.81      0.80      0.79      2665

# %%
param_grid = {'C': [1,0.1,10,100,1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']}

# %%
grid_search = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)
grid_search.fit(text_train,target_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.612 total time=   4.3s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0
]
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83      1489
#            1       0.87      0.63      0.73      1176
#
#     accuracy                           0.80      2665
#    macro avg       0.81      0.78      0.78      2665
# weighted avg       0.81      0.80      0.79      2665

# %%
xgb = XGBClassifier(use_label_encoder=False,
                    objective='binary:logistic',
                    n_estimators=1000,
                    tree_method='hist',
                    booster='gbtree'
                   )

# %%
eval_set = [(text_train, target_train), (text_test, target_test)]

# %%
xgb.fit(text_train,
        target_train,
        early_stopping_rounds=5,
        eval_set=eval_set
       )
# Out:
# [20:47:50] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.65983	validation_1-logloss:0.66604
# [1]	validation_0-logloss:0.64167	validation_1-logloss:0.65279
# [2]	validation_0-logloss:0.62837	validation_1-logloss:0.64280
# [3]	validation_0-logloss:0.61749	validation_1-logloss:0.63336
# [4]	validation_0-logloss:0.60721	validation_1-logloss:0.62601
# [5]	validation_0-logloss:0.59854	validation_1-logloss:0.61711
# [6]	validation_0-logloss:0.58975	validation_1-logloss:0.60970
# [7]	validation_0-logloss:0.58300	validation_1-logloss:0.60514
# [8]	validation_0-logloss:0.57592	validation_1-logloss:0.59950
# [9]	validation_0-logloss:0.56990	validation_1-logloss:0.59620
# [10]	validation_0-logloss:0.56381	validation_1-logloss:0.59213
# [11]	validation_0-logloss:0.55853	validation_1-logloss:0.58757
# [12]	validation_0-logloss:0.55391	validation_1-logloss:0.58355
# [13]	validation_0-logloss:0.54936	validation_1-logloss:0.58080
# [14]	validation_0-logloss:0.54432	validation_1-logloss:0.57697
# [15]	validation_0-logloss:0.53975	validation_1-logloss:0.57260
# [16]	validation_0-logloss:0.53582	validation_1-logloss:0.57001
# [17]	validation_0-logloss:0.53234	validation_1-logloss:0.56737
# [18]	validation_0-logloss:0.52878	validation_1-logloss:0.56579
# [19]	validation_0-logloss:0.52521	validation_1-logloss:0.56307
# [20]	validation_0-logloss:0.52192	validation_1-logloss:0.55993
# [21]	validation_0-logloss:0.51887	validation_1-logloss:0.55785
# [22]	validation_0-logloss:0.51576	validation_1-logloss:0.55541
# [23]	validation_0-logloss:0.51284	validation_1-logloss:0.55378
# [24]	validation_0-logloss:0.50975	validation_1-logloss:0.55114
# [25]	validation_0-logloss:0.50685	validation_1-logloss:0.54857
# [26]	validation_0-logloss:0.50400	validation_1-logloss:0.54651
# [27]	validation_0-logloss:0.50131	validation_1-logloss:0.54403
# [28]	validation_0-logloss:0.49886	validation_1-logloss:0.54242
# [29]	validation_0-logloss:0.49655	validation_1-logloss:0.54039
# [30]	validation_0-logloss:0.49408	validation_1-logloss:0.53921
# [31]	validation_0-logloss:0.49165	validation_1-logloss:0.53839
# [32]	validation_0-logloss:0.48942	validation_1-logloss:0.53711
# [33]	validation_0-logloss:0.48713	validation_1-logloss:0.53514
# [34]	validation_0-logloss:0.48499	validation_1-logloss:0.53366
# [35]	validation_0-logloss:0.48244	validation_1-logloss:0.53261
# [36]	validation_0-logloss:0.48049	validation_1-logloss:0.53186
# [37]	validation_0-logloss:0.47853	validation_1-logloss:0.53072
# [38]	validation_0-logloss:0.47629	validation_1-logloss:0.52854
# [39]	validation_0-logloss:0.47408	validation_1-logloss:0.52788
# [40]	validation_0-logloss:0.47207	validation_1-logloss:0.52623
# [41]	validation_0-logloss:0.47032	validation_1-logloss:0.52477
# [42]	validation_0-logloss:0.46866	validation_1-logloss:0.52402
# [43]	validation_0-logloss:0.46702	validation_1-logloss:0.52264
# [44]	validation_0-logloss:0.46521	validation_1-logloss:0.52221
# [45]	validation_0-logloss:0.46348	validation_1-logloss:0.52077
# [46]	validation_0-logloss:0.46152	validation_1-logloss:0.51927
# [47]	validation_0-logloss:0.45997	validation_1-logloss:0.51848
# [48]	validation_0-logloss:0.45843	validation_1-logloss:0.51748
# [49]	validation_0-logloss:0.45687	validation_1-logloss:0.51698
# [50]	validation_0-logloss:0.45539	validation_1-logloss:0.51666
# [51]	validation_0-logloss:0.45400	validation_1-logloss:0.51524
# [52]	validation_0-logloss:0.45257	validation_1-logloss:0.51428
# [53]	validation_0-logloss:0.45122	validation_1-logloss:0.51328
# [54]	validation_0-logloss:0.44961	validation_1-logloss:0.51339
# [55]	validation_0-logloss:0.44819	validation_1-logloss:0.51235
# [56]	validation_0-logloss:0.44683	validation_1-logloss:0.51196
# [57]	validation_0-logloss:0.44540	validation_1-logloss:0.51097
# [58]	validation_0-logloss:0.44396	validation_1-logloss:0.51020
# [59]	validation_0-logloss:0.44233	validation_1-logloss:0.50914
# [60]	validation_0-logloss:0.44115	validation_1-logloss:0.50856
# [61]	validation_0-logloss:0.43901	validation_1-logloss:0.50755
# [62]	validation_0-logloss:0.43772	validation_1-logloss:0.50694
# [63]	validation_0-logloss:0.43648	validation_1-logloss:0.50630
# [64]	validation_0-logloss:0.43525	validation_1-logloss:0.50538
# [65]	validation_0-logloss:0.43400	validation_1-logloss:0.50464
# [66]	validation_0-logloss:0.43284	validation_1-logloss:0.50389
# [67]	validation_0-logloss:0.43169	validation_1-logloss:0.50358
# [68]	validation_0-logloss:0.43048	validation_1-logloss:0.50297
# [69]	validation_0-logloss:0.42937	validation_1-logloss:0.50243
# [70]	validation_0-logloss:0.42813	validation_1-logloss:0.50144
# [71]	validation_0-logloss:0.42706	validation_1-logloss:0.50079
# [72]	validation_0-logloss:0.42608	validation_1-logloss:0.50019
# [73]	validation_0-logloss:0.42506	validation_1-logloss:0.49958
# [74]	validation_0-logloss:0.42399	validation_1-logloss:0.49931
# [75]	validation_0-logloss:0.42285	validation_1-logloss:0.49850
# [76]	validation_0-logloss:0.42182	validation_1-logloss:0.49839
# [77]	validation_0-logloss:0.42077	validation_1-logloss:0.49795
# [78]	validation_0-logloss:0.41974	validation_1-logloss:0.49743
# [79]	validation_0-logloss:0.41884	validation_1-logloss:0.49731
# [80]	validation_0-logloss:0.41781	validation_1-logloss:0.49627
# [81]	validation_0-logloss:0.41668	validation_1-logloss:0.49606
# [82]	validation_0-logloss:0.41576	validation_1-logloss:0.49606
# [83]	validation_0-logloss:0.41486	validation_1-logloss:0.49554
# [84]	validation_0-logloss:0.41400	validation_1-logloss:0.49519
# [85]	validation_0-logloss:0.41306	validation_1-logloss:0.49491
# [86]	validation_0-logloss:0.41212	validation_1-logloss:0.49401
# [87]	validation_0-logloss:0.41114	validation_1-logloss:0.49331
# [88]	validation_0-logloss:0.41013	validation_1-logloss:0.49243
# [89]	validation_0-logloss:0.40922	validation_1-logloss:0.49200
# [90]	validation_0-logloss:0.40834	validation_1-logloss:0.49164
# [91]	validation_0-logloss:0.40748	validation_1-logloss:0.49125
# [92]	validation_0-logloss:0.40659	validation_1-logloss:0.49135
# [93]	validation_0-logloss:0.40576	validation_1-logloss:0.49104
# [94]	validation_0-logloss:0.40477	validation_1-logloss:0.49030
# [95]	validation_0-logloss:0.40397	validation_1-logloss:0.49030
# [96]	validation_0-logloss:0.40318	validation_1-logloss:0.49014
# [97]	validation_0-logloss:0.40229	validation_1-logloss:0.48924
# [98]	validation_0-logloss:0.40139	validation_1-logloss:0.48902
# [99]	validation_0-logloss:0.40027	validation_1-logloss:0.48838
# [100]	validation_0-logloss:0.39944	validation_1-logloss:0.48833
# [101]	validation_0-logloss:0.39868	validation_1-logloss:0.48819
# [102]	validation_0-logloss:0.39788	validation_1-logloss:0.48814
# [103]	validation_0-logloss:0.39698	validation_1-logloss:0.48795
# [104]	validation_0-logloss:0.39625	validation_1-logloss:0.48760
# [105]	validation_0-logloss:0.39523	validation_1-logloss:0.48735
# [106]	validation_0-logloss:0.39439	validation_1-logloss:0.48660
# [107]	validation_0-logloss:0.39370	validation_1-logloss:0.48624
# [108]	validation_0-logloss:0.39298	validation_1-logloss:0.48590
# [109]	validation_0-logloss:0.39227	validation_1-logloss:0.48554
# [110]	validation_0-logloss:0.39149	validation_1-logloss:0.48558
# [111]	validation_0-logloss:0.39080	validation_1-logloss:0.48533
# [112]	validation_0-logloss:0.39013	validation_1-logloss:0.48498
# [113]	validation_0-logloss:0.38947	validation_1-logloss:0.48488
# [114]	validation_0-logloss:0.38884	validation_1-logloss:0.48469
# [115]	validation_0-logloss:0.38811	validation_1-logloss:0.48447
# [116]	validation_0-logloss:0.38730	validation_1-logloss:0.48456
# [117]	validation_0-logloss:0.38668	validation_1-logloss:0.48407
# [118]	validation_0-logloss:0.38594	validation_1-logloss:0.48325
# [119]	validation_0-logloss:0.38523	validation_1-logloss:0.48295
# [120]	validation_0-logloss:0.38453	validation_1-logloss:0.48276
# [121]	validation_0-logloss:0.38392	validation_1-logloss:0.48246
# [122]	validation_0-logloss:0.38324	validation_1-logloss:0.48236
# [123]	validation_0-logloss:0.38263	validation_1-logloss:0.48230
# [124]	validation_0-logloss:0.38205	validation_1-logloss:0.48246
# [125]	validation_0-logloss:0.38140	validation_1-logloss:0.48195
# [126]	validation_0-logloss:0.38058	validation_1-logloss:0.48144
# [127]	validation_0-logloss:0.37979	validation_1-logloss:0.48100
# [128]	validation_0-logloss:0.37916	validation_1-logloss:0.48062
# [129]	validation_0-logloss:0.37846	validation_1-logloss:0.48046
# [130]	validation_0-logloss:0.37787	validation_1-logloss:0.48039
# [131]	validation_0-logloss:0.37732	validation_1-logloss:0.48025
# [132]	validation_0-logloss:0.37676	validation_1-logloss:0.48011
# [133]	validation_0-logloss:0.37621	validation_1-logloss:0.48004
# [134]	validation_0-logloss:0.37564	validation_1-logloss:0.48011
# [135]	validation_0-logloss:0.37495	validation_1-logloss:0.47971
# [136]	validation_0-logloss:0.37434	validation_1-logloss:0.47942
# [137]	validation_0-logloss:0.37381	validation_1-logloss:0.47934
# [138]	validation_0-logloss:0.37329	validation_1-logloss:0.47941
# [139]	validation_0-logloss:0.37260	validation_1-logloss:0.47952
# [140]	validation_0-logloss:0.37198	validation_1-logloss:0.47915
# [141]	validation_0-logloss:0.37142	validation_1-logloss:0.47867
# [142]	validation_0-logloss:0.37072	validation_1-logloss:0.47893
# [143]	validation_0-logloss:0.37017	validation_1-logloss:0.47885
# [144]	validation_0-logloss:0.36962	validation_1-logloss:0.47932
# [145]	validation_0-logloss:0.36909	validation_1-logloss:0.47902
# [146]	validation_0-logloss:0.36850	validation_1-logloss:0.47936
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=1000, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='hist', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
xgb_predictions = xgb.predict(text_test)
xgb_predictions
# Out:
# array([0, 1, 1, ..., 0, 1, 0])

# %%
print(confusion_matrix(target_test,xgb_predictions))
print(classification_report(target_test,xgb_predictions))
# Out:
# [[1325  164]
#  [ 432  744]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.89      0.82      1489
#            1       0.82      0.63      0.71      1176
#
#     accuracy                           0.78      2665
#    macro avg       0.79      0.76      0.77      2665
# weighted avg       0.78      0.78      0.77      2665

# %% [markdown]
# # Conclusion

# %%
print('Performance of ML Models:')
print('Prediction Accuracy of Logistic Regression:',str(np.round(accuracy_score(target_test,lr_pred)*100,2)) + '%')
print('Prediction Accuracy of K Nearest Neighbors:',str(np.round(accuracy_score(target_test,knn_pred)*100,2)) + '%')
print('Prediction Accuracy of Support Vector Machines Classifier:',str(np.round(accuracy_score(target_test,svm_pred)*100,2)) + '%')
print('Prediction Accuracy of Decision Tree Classifier:',str(np.round(accuracy_score(target_test,dtree_pred)*100,2)) + '%')
print('Prediction Accuracy of Random Forests Classifier:',str(np.round(accuracy_score(target_test,lr_pred)*100,2)) + '%')
print('Prediction Accuracy of Multinomial Naive Bayes:',str(np.round(accuracy_score(target_test,predictions)*100,2)) + '%')
print('Prediction Accuracy of Optimized K Nearest Neighbors:',str(np.round(accuracy_score(target_test,optimized_knn)*100,2)) + '%')
print('Prediction Accuracy of XGBoost Classifier:',str(np.round(accuracy_score(target_test,xgb_predictions)*100,2)) + '%')
# Out:
# Performance of ML Models:
# Prediction Accuracy of Logistic Regression: 79.06%
# Prediction Accuracy of K Nearest Neighbors: 66.23%
# Prediction Accuracy of Support Vector Machines Classifier: 79.62%
# Prediction Accuracy of Decision Tree Classifier: 75.38%
# Prediction Accuracy of Random Forests Classifier: 79.06%
# Prediction Accuracy of Multinomial Naive Bayes: 80.53%
# Prediction Accuracy of Optimized K Nearest Neighbors: 68.89%
# Prediction Accuracy of Optimized Support Vector Classifier: 79.59%
# Prediction Accuracy of XGBoost Classifier: 77.64%

# %% [markdown]
# ## Predicting on test data

# %%
bow_text.shape, bow_text_test.shape
# Out:
# ((7613, 18866), (3263, 10569))

# %%
predictions = mnb.predict(bow_text_test)
predictions
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
assert(len(predictions) == test.shape[0])

# %%
predictions = pd.DataFrame(predictions)
idx = test.id
final_df = pd.concat([idx,predictions],axis=1)
final_df.columns = ['id','target']
final_df.head()
# Out:
#    id  target
# 0   0       1
# 1   2       1
# 2   3       1
# 3   9       1
# 4  11       1

# %%
final_df.to_csv('tweet_disaster_prediction.csv',index=False)
